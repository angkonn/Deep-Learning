# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),
    

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss = "binary_crossentropy",
    metrics = ['binary_accuracy']
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1742385583.501731     103 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/80 [==============================] - 27s 267ms/step - loss: 0.6771 - binary_accuracy: 0.5792 - val_loss: 0.6665 - val_binary_accuracy: 0.6011
# Epoch 2/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6633 - binary_accuracy: 0.5992 - val_loss: 0.6523 - val_binary_accuracy: 0.6205
# Epoch 3/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6542 - binary_accuracy: 0.6142 - val_loss: 0.6434 - val_binary_accuracy: 0.6290
# Epoch 4/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6458 - binary_accuracy: 0.6199 - val_loss: 0.6380 - val_binary_accuracy: 0.6258
# Epoch 5/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6321 - binary_accuracy: 0.6389 - val_loss: 0.6235 - val_binary_accuracy: 0.6486
# Epoch 6/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6229 - binary_accuracy: 0.6467 - val_loss: 0.6173 - val_binary_accuracy: 0.6529
# Epoch 7/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.6052 - binary_accuracy: 0.6635 - val_loss: 0.5969 - val_binary_accuracy: 0.6759
# Epoch 8/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5901 - binary_accuracy: 0.6779 - val_loss: 0.5931 - val_binary_accuracy: 0.6779
# Epoch 9/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5731 - binary_accuracy: 0.6938 - val_loss: 0.5706 - val_binary_accuracy: 0.7106
# Epoch 10/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5487 - binary_accuracy: 0.7073 - val_loss: 0.5498 - val_binary_accuracy: 0.7254
# Epoch 11/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5286 - binary_accuracy: 0.7235 - val_loss: 0.5092 - val_binary_accuracy: 0.7535
# Epoch 12/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4988 - binary_accuracy: 0.7407 - val_loss: 0.5022 - val_binary_accuracy: 0.7535
# Epoch 13/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4640 - binary_accuracy: 0.7753 - val_loss: 0.4887 - val_binary_accuracy: 0.7646
# Epoch 14/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4419 - binary_accuracy: 0.7958 - val_loss: 0.5012 - val_binary_accuracy: 0.7585
# Epoch 15/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4164 - binary_accuracy: 0.8071 - val_loss: 0.4705 - val_binary_accuracy: 0.7767
# Epoch 16/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.4011 - binary_accuracy: 0.8128 - val_loss: 0.4441 - val_binary_accuracy: 0.7947
# Epoch 17/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3641 - binary_accuracy: 0.8310 - val_loss: 0.4686 - val_binary_accuracy: 0.7701
# Epoch 18/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3520 - binary_accuracy: 0.8394 - val_loss: 0.4284 - val_binary_accuracy: 0.8046
# Epoch 19/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.3097 - binary_accuracy: 0.8579 - val_loss: 0.4575 - val_binary_accuracy: 0.7818
# Epoch 20/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2962 - binary_accuracy: 0.8646 - val_loss: 0.4278 - val_binary_accuracy: 0.8056
# Epoch 21/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2871 - binary_accuracy: 0.8706 - val_loss: 0.4562 - val_binary_accuracy: 0.8072
# Epoch 22/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2576 - binary_accuracy: 0.8798 - val_loss: 0.4814 - val_binary_accuracy: 0.8018
# Epoch 23/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2350 - binary_accuracy: 0.8956 - val_loss: 0.4853 - val_binary_accuracy: 0.8036
# Epoch 24/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2296 - binary_accuracy: 0.8951 - val_loss: 0.4567 - val_binary_accuracy: 0.8200
# Epoch 25/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2007 - binary_accuracy: 0.9101 - val_loss: 0.5079 - val_binary_accuracy: 0.8226
# Epoch 26/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2070 - binary_accuracy: 0.9035 - val_loss: 0.4487 - val_binary_accuracy: 0.8244
# Epoch 27/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2057 - binary_accuracy: 0.9052 - val_loss: 0.5020 - val_binary_accuracy: 0.8054
# Epoch 28/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2434 - binary_accuracy: 0.8831 - val_loss: 0.4830 - val_binary_accuracy: 0.8226
# Epoch 29/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.2173 - binary_accuracy: 0.8992 - val_loss: 0.5526 - val_binary_accuracy: 0.8137
# Epoch 30/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1777 - binary_accuracy: 0.9193 - val_loss: 0.5868 - val_binary_accuracy: 0.8137
# Epoch 31/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1480 - binary_accuracy: 0.9341 - val_loss: 0.6075 - val_binary_accuracy: 0.8147
# Epoch 32/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1303 - binary_accuracy: 0.9351 - val_loss: 0.6238 - val_binary_accuracy: 0.8276
# Epoch 33/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1137 - binary_accuracy: 0.9500 - val_loss: 0.5930 - val_binary_accuracy: 0.8388
# Epoch 34/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1206 - binary_accuracy: 0.9455 - val_loss: 0.5911 - val_binary_accuracy: 0.8347
# Epoch 35/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1292 - binary_accuracy: 0.9429 - val_loss: 0.5180 - val_binary_accuracy: 0.8432
# Epoch 36/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1325 - binary_accuracy: 0.9414 - val_loss: 0.6137 - val_binary_accuracy: 0.8307
# Epoch 37/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1135 - binary_accuracy: 0.9492 - val_loss: 0.5338 - val_binary_accuracy: 0.8406
# Epoch 38/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1203 - binary_accuracy: 0.9482 - val_loss: 0.5714 - val_binary_accuracy: 0.8369
# Epoch 39/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1132 - binary_accuracy: 0.9537 - val_loss: 0.5674 - val_binary_accuracy: 0.8179
# Epoch 40/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.1225 - binary_accuracy: 0.9490 - val_loss: 0.4990 - val_binary_accuracy: 0.8109
# Epoch 41/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0956 - binary_accuracy: 0.9607 - val_loss: 0.5126 - val_binary_accuracy: 0.8559
# Epoch 42/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0732 - binary_accuracy: 0.9724 - val_loss: 0.6458 - val_binary_accuracy: 0.8533
# Epoch 43/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0567 - binary_accuracy: 0.9767 - val_loss: 0.6931 - val_binary_accuracy: 0.8543
# Epoch 44/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0538 - binary_accuracy: 0.9787 - val_loss: 0.6995 - val_binary_accuracy: 0.8507
# Epoch 45/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0436 - binary_accuracy: 0.9844 - val_loss: 0.8121 - val_binary_accuracy: 0.8531
# Epoch 46/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0450 - binary_accuracy: 0.9810 - val_loss: 0.7184 - val_binary_accuracy: 0.8577
# Epoch 47/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0429 - binary_accuracy: 0.9824 - val_loss: 0.8411 - val_binary_accuracy: 0.8529
# Epoch 48/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0390 - binary_accuracy: 0.9861 - val_loss: 0.8841 - val_binary_accuracy: 0.8543
# Epoch 49/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0404 - binary_accuracy: 0.9850 - val_loss: 0.8505 - val_binary_accuracy: 0.8483
# Epoch 50/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.0350 - binary_accuracy: 0.9881 - val_loss: 0.8972 - val_binary_accuracy: 0.8557

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
